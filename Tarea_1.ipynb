# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/Curso-Python-2023/blob/main/Tarea_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Tarea 1</h1>
#
# **Fecha límite de entrega: 8 de noviembre**

# %% [markdown]
# # 1. Ejercicios

# %% [markdown]
# 🔴 Resuelve los siguientes ejercicios.

# %% [markdown]
# 1. Obtener la entrada del usuario usando la función `input`. Si el usuario tiene 18 años o más, dar respuesta: **`Eres mayor de edad`**. Si tiene menos de 18 años, indicar que hay que esperar **`la cantidad de años que le faltan`**.
#
# Salida:
#
# ```py
#     Introduzca su edad: 30
#     Eres mayor de edad.
# ```
#
# Salida:
# ```py
#     Introduce tu edad: 15
#     Necesitas esperar 3 años más para ser mayor de edad.
# ```

# %%
# Tu código aquí...

# %% [markdown]
# 2. Imprimir todos los números del 1 al 50 indicando si cada uno de ellos es par o impar.
#
# Salida:
#
# ```py
#     1 es un número impar
#     2 es un número par
#     3 es un número impar
#     ...
# ```

# %%
# Tu código aquí...

# %% [markdown]
# 3. Imprimir todos los múltiplos de 3 que estén entre 1 y 100.
#
# Salida:
#
# ```py
#     Multiplos de 7:
#     3
#     6
#     9
#     ...
# ```

# %%
# Tu código aquí...

# %% [markdown]
# 4. Considere la función de variable real $f(x) = x^2$. Cree una lista de Python cuyos elementos sean tuplas $(k, f(x))$, con $k$ un número entero entre $-10$ y $10$. Es decir, una lista como la siguiente:
# ```
# [(-10,100), (-9,81), ..., (0,0), ..., (9,81), (10,100)]
# ```
# Guarde la lista en una variable con nombre ```parejas```

# %%
# Tu código aquí...

# %% [markdown]
# 5. Invierta el orden de la lista `parejas`

# %%
# Tu código aquí...

# %% [markdown]
# 6. Recorra la lista `parejas` de izquierda a derecha y extraiga las tuplas cuyos primeros elementos sean enteros pares.

# %%
# Tu código aquí...

# %% [markdown]
# 7. Recorra la lista `parejas` de izquierda a derecha y extraiga las tuplas cuyos primeros elementos sean enteros impares.

# %%
# Tu código aquí...

# %% [markdown]
# 8. Recorra la lista `parejas` de derecha a izquierda y extraiga las tuplas cuyos primeros elementos sean enteros pares.

# %%
# Tu código aquí...

# %% [markdown]
# 9. Recorra la lista `parejas` de derecha a izquierda y extraiga las tuplas cuyos primeros elementos sean enteros impares.

# %%
# Tu código aquí...

# %% [markdown]
# 10. Recorra la lista `parejas` de izquierda a derecha y extraiga las tuplas cuyos primeros elementos sean enteros múltiplos de 3.

# %%
# Tu código aquí...

# %% [markdown]
# 11. Recorra la lista `parejas` de izquierda a derecha y extraiga las tuplas cuyos primeros elementos sean enteros múltiplos de 4.

# %%
# Tu código aquí...

# %% [markdown]
# 12. Considere la siguiente tabla de calificaciones:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Cree un diccionario que recopile la información de la tabla anterior de la siguiente manera: que las claves del diccionario sean cada uno de los nombres de los alumnos y los correspondientes valores del diccionario las (correspondientes) calificaciones.
#
# Guarde la lista en una variable con nombre ```calificaciones```

# %%
# Tu código aquí...

# %% [markdown]
# 13. Imprima las calificaciones de los alumnos cuyos nombres comiencen con A y R.

# %%
# Tu código aquí...

# %% [markdown]
# 14. Agregue al diccionario `calificaciones` las calificaciones de los siguientes alumnos:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Tu código aquí...

# %% [markdown]
# 15. Actualice en el diccionario `calificaciones` las siguientes calificaciones:
#
# | Nombre | Nueva Calificación |
# | :--------: | ------------   |
# | Rodrigo    | 6.7 |
# | Diana      | 9.5 |
# | Sandra     | 8.8 |
# | Alex       | 7.9 |

# %%
# Tu código aquí...

# %% [markdown]
# # 2. Encontrar raíces de funciones reales

# %% [markdown]
# ## Funciones

# %% [markdown]
# Para poder implementar algunos de los algoritmos (clásicos) que permiten encontrar los ceros de una función de variable real necesitamos, en particular, una manera de hacer que Python pueda evaluar una tal función. Para lo anterior, podemos usar una sintaxis de código que Python provee para definir una "función de Python".
#
# En Python, una función es un bloque de código organizado, reutilizable, que se usa para realizar una única tarea específica. Puede tomar argumentos y puede devuelve algún valor.
#
# **Syntaxis:**
#
# ```python
# def function_name(parameter1, parameter2, ...):
#     # function body
#     return value # Opcional
# ```

# %% [markdown]
# **Ejemplo:** Define una función que calcule el error relativo entre un valor real y un valor numérico. El error relativo está dado por
#
# $$E_r(v,a) = \left|\frac{v-a}{v}\right|$$
#
# donde $v$ es el valor real y $a$ es una aproximación a dicho valor real.

# %%
from math import fabs   #sobre fabs: https://docs.python.org/3/library/math.html#math.fabs

def error_relativo(valor_real, valor_aproximado):
    return fabs((valor_real - valor_aproximado)/valor_real)

# %% [markdown]
# **🔴 Ejercicio:** Implementa una función de Python que evalue la función $f:\mathbb{R}\rightarrow\mathbb{R}$ dada por
#
# $$f(x)=x^3 - 4x^2 + 6x - 24 $$
# en algún valor $x \in \mathbb{R}$.

# %%
def f(x):
    return # borra este comentario y escriba el código necesario

# %% [markdown]
# ## Metodo de falsa posición

# %% [markdown]
# **Recordemos que** (Chapra, S. C., Canale, R. P., Ruiz, R. S. G., Mercado, V. H. I., Díaz, E. M., & Benites, G. E. (2011). Métodos numéricos para ingenieros. New York, NY, USA: McGraw-Hill.)**:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A continuación se presenta una manera de implementar el algoritmo de la Falsa Posición. Lo aplicamos para resolver la ecuación
#
# $$f(x)=x^3 - 4x^2 + 6x - 24 = 0$$
#
# en el intervalo $[3,6]$. Recuerda que ya hemos definido anteriormente la función $f$. La solución es $x=4$.
#
# **Analiza el código y compárala con la descripción del método en el libro**

# %%
# Definimos los extremos del intervalo donde se encuentra la raiz:
x0 = 3
x1 = 6

# Definimos la tolerancia con la que queremos encontrar la raiz:
tolerancia = 0.00001

# ------------------------
# El algoritmo:
# ------------------------

xm = x0                 # Inicializamos el punto dentro del intervalo [x0,x1] que es la nueva aproximacion
error = 2*tolerancia    # Para asegurar que entremos al ciclo while la primera vez
while (error>tolerancia):
    xm_anterior = xm
    xm = x1 - (f(x1)*(x0-x1))/(f(x0)-f(x1))
    if xm != 0:
        error = error_relativo(xm,xm_anterior)
    test = f(x0)*f(xm)
    if test<0:
        x1 = xm
    elif test>0:
        x0 = xm
    else:
        error = 0

print(f"Solución aproximada: {xm}")
print(f"Error relativo aproximado: {error}")
print(f"Evaluación de la función en la aproximación obtenida: {f(xm)}")

# %% [markdown]
# ## Método de la bisección

# %% [markdown]
# **🔴 Ejercicio:** Usando como referencia el método de la falsa posición, implementa el método de la bisección para resolver la misma ecuación (anterior) en el mismo intervalo, con una toleracia de $0.00001$

# %%
# Tu código aquí...

# %% [markdown]
# ## Método de la secante

# %% [markdown]
# **Recordemos que** (Chapra, S. C., Canale, R. P., Ruiz, R. S. G., Mercado, V. H. I., Díaz, E. M., & Benites, G. E. (2011). Métodos numéricos para ingenieros. New York, NY, USA: McGraw-Hill.)**:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A continuación se presenta una implementación del método de la secante. Lo aplicamos para resolver la ecuación
#
# $$f(x)=x^3 - 4x^2 + 6x - 24 = 0$$
#
# Recuerda que ya hemos definido anteriormente la función $f$.
#
# **Analiza el código y compárala con la descripción del método en el libro**

# %%
# Definimos los extremos del intervalo donde se encuentra la raiz, por ejemplo:
x0 = 0
x1 = 2

# Definimos la tolerancia:
tolerancia = 0.00001

# ------------------------
# El algoritmo:
# ------------------------

error = 2*tolerancia    # Para asegurar que entremos al ciclo while la primera vez
while (error>tolerancia):
    x_siguiente = x1 - f(x1)*(x0-x1)/(f(x0)-f(x1))
    if x1 != 0:
        error = error_relativo(x_siguiente,x1)
    x0 = x1
    x1 = x_siguiente

print(f"Solución aproximada: {x_siguiente}")
print(f"Error relativo aproximado: {error}")
print(f"Evaluación de la función en la aproximación obtenida: {f(x_siguiente)}")

# %% [markdown]
# ## Método de iteración de punto fijo

# %% [markdown]
# **🔴 Ejercicio:** Usando como referencia los métodos anteriores, implementa el método de iteración de punto fijo para resolver la misma ecuación (anterior), con una toleracia de $0.00001$.

# %%
# Tu código aquí...
